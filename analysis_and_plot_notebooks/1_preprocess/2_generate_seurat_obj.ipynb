# %%
library(tidyverse)
library(Seurat)
library(patchwork)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.8
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Registered S3 method overwritten by 'spatstat.geom':
#   method     from
#   print.boxx cli
#
# Attaching SeuratObject

# %%
rna_mat <- read_tsv("/shareb/zliu/analysis/hires_mouse_dev/submission/submitfiles/RNA_mat/HiRES_emb.rna.umicount.tsv")
metadata <- readxl::read_excel(path = "/shareb/zliu/analysis/hires_mouse_dev/submission/submitfiles/HiRES_emb_metadata.xlsx")
# Out:
# Rows: 50463 Columns: 7470
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr    (1): gene
# dbl (7469): GasaE751001, GasaE751002, GasaE751003, GasaE751004, GasaE751005,...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
options(repr.matrix.max.cols = 50)
metadata
# Out:
#      Cellname     Rawreads  DNAreads  RNAreads  y/x      Raw contacts
# 1    GasaE751001  0.7889634 0.7041564 0.0732138 0.010131  293142
# 2    GasaE751002  1.1945130 1.1176506 0.0659949 0.028088  593838
# 3    GasaE751003  1.0066968 0.9381633 0.0590820 0.021442  398891
# 4    GasaE751004  1.1271210 1.0191219 0.0943068 0.021927  407136
# 5    GasaE751005  2.8412850 2.6502027 0.1668774 0.023697 1095973
# 6    GasaE751006  2.7738111 2.6750514 0.0848223 0.001070 1243739
# 7    GasaE751007  3.7529382 3.6911481 0.0504789 0.017872 1664740
# 8    GasaE751008  3.5375043 3.4400223 0.0830373 0.001192 1951984
# 9    GasaE751009  1.4844930 1.2720858 0.1872030 0.016725  597809
# 10   GasaE751010  1.5694980 1.4348172 0.1180425 0.013619  676133
# 11   GasaE751011  1.8772674 1.6829547 0.1693437 0.007384  762497
# 12   GasaE751012  1.8305601 1.6828299 0.1290252 0.022155  865058
# 13   GasaE751013  1.3026636 1.2656142 0.0309873 0.001264  560097
# ...
